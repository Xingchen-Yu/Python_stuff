# %% [markdown]
# ## [A Short Chronology Of Deep Learning For Tabular Data](https://sebastianraschka.com/blog/2022/deep-learning-for-tabular-data.html)

# %% [markdown]
# - Solid experiments and thorough investigation into the role of uninformative features: uninformative features harm deep learning methods more than tree-based methods.
#
# - The gap between tree-based models and deep learning becomes narrower as the dataset size increases (here: 10k -> 50k).
#
# - Another takeaway is that XGBoost requires substantially less hyperparameter tuning to perform well, which is a significant benefit in many real-life scenarios.

# %% [markdown]
# ## Papers worth reading
#
# - [Scalable Interpretability via Polynomials](https://arxiv.org/pdf/2205.14108.pdf)
# - [Neural Basis Models for Interpretability](https://arxiv.org/pdf/2205.14120.pdf)
# - [Neural Additive Models: Interpretable Machine Learning with Neural Nets](https://arxiv.org/abs/2004.13912)
#
# Interpretable DL for Tabular data, reverse chronical order
#
# - [DANETs: Deep Abstract Networks for Tabular Data Classification and Regression (2021-12)](https://arxiv.org/abs/2112.02962)
#
# Does group variable selection, stack similar feature as block.
#
# - [Why do tree-based models still outperform deep learning on tabular data?](https://arxiv.org/pdf/2207.08815.pdf)
#     -  [FT_Transformer](https://arxiv.org/pdf/2106.11959.pdf)
#     -  [SAINT](https://arxiv.org/abs/2106.01342)
#
# Well-tuned Simple Nets Excel on Tabular Datasets

# %% [markdown]
# ## XGBoost tuning parameter recommendation suggested by Bojan Tunguz

# %% [markdown]
# ![image.png](attachment:a128ebae-c700-4213-a5cc-64ea2e473b00.png)![image.png](attachment:d37a640f-4760-40f1-8451-0d4955b25963.png)
