# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.discrete.count_model import ZeroInflatedPoisson

# Generate sample data
np.random.seed(0)
n = 1000
X1 = np.random.randn(n)
X2 = np.random.randn(n)

# Generate response variable with excess zeros
lambda_ = np.exp(1 + 0.5 * X1 - 0.5 * X2)
prob_zero = 1 / (1 + np.exp(-(0.5 - X1 + 0.5 * X2)))
y = np.random.poisson(lambda_)
y[np.random.random(n) < prob_zero] = 0

# Create a DataFrame
df = pd.DataFrame({'y': y, 'X1': X1, 'X2': X2})

# Prepare the data for ZeroInflatedPoisson
exog = sm.add_constant(df[['X1', 'X2']])
exog_infl = sm.add_constant(df[['X1', 'X2']])

# Fit Zero-Inflated Poisson model
zip_model = ZeroInflatedPoisson(df['y'], exog, exog_infl=exog_infl)
zip_results = zip_model.fit()

# Print summary
print(zip_results.summary())

# Access coefficients
print("\nCount model coefficients:")
print(zip_results.params[:3])  # First 3 are for the count model
print("\nZero-inflation model coefficients:")
print(zip_results.params[3:])  # Last 3 are for the zero-inflation model

# Predict
new_data = pd.DataFrame({'X1': [0.5, -0.5], 'X2': [-0.5, 0.5]})
new_exog = sm.add_constant(new_data)
predicted = zip_results.predict(new_exog, exog_infl=new_exog)
print("\nPredicted counts for new data:")
print(predicted)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.279062
#          Iterations: 18
#          Function evaluations: 20
#          Gradient evaluations: 20
#                      ZeroInflatedPoisson Regression Results
# ===============================================================================
# Dep. Variable:                       y   No. Observations:                 1000
# Model:             ZeroInflatedPoisson   Df Residuals:                      997
# Method:                            MLE   Df Model:                            2
# Date:                 Sun, 29 Sep 2024   Pseudo R-squ.:                  0.2666
# Time:                         21:14:12   Log-Likelihood:                -1279.1
# converged:                        True   LL-Null:                       -1744.1
# Covariance Type:             nonrobust   LLR p-value:                1.085e-202
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# inflate_const     0.4253      0.081      5.283      0.000       0.268       0.583
# inflate_X1       -1.0143      0.095    -10.632      0.000      -1.201      -0.827
# inflate_X2        0.5456      0.088      6.184      0.000       0.373       0.719
# const             0.9547      0.039     24.362      0.000       0.878       1.031
# X1                0.5426      0.027     19.789      0.000       0.489       0.596
# X2               -0.4733      0.025    -18.680      0.000      -0.523      -0.424
# =================================================================================
#
# Count model coefficients:
# inflate_const    0.425337
# inflate_X1      -1.014316
# inflate_X2       0.545600
# dtype: float64
#
# Zero-inflation model coefficients:
# const    0.954661
# X1       0.542627
# X2      -0.473277
# dtype: float64
#
# Predicted counts for new data:
# 0    2.537396
# 1    0.360363
# dtype: float64

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.discrete.count_model import ZeroInflatedNegativeBinomialP

# Generate sample data
np.random.seed(0)
n = 1000
X1 = np.random.randn(n)
X2 = np.random.randn(n)

# Generate response variable with excess zeros and overdispersion
lambda_ = np.exp(1 + 0.5 * X1 - 0.5 * X2)
prob_zero = 1 / (1 + np.exp(-(0.5 - X1 + 0.5 * X2)))
y = np.random.negative_binomial(n=5, p=5/(5+lambda_))  # Using NB parameterization
y[np.random.random(n) < prob_zero] = 0

# Create a DataFrame
df = pd.DataFrame({'y': y, 'X1': X1, 'X2': X2})

# Prepare the data for ZeroInflatedNegativeBinomialP
exog = sm.add_constant(df[['X1', 'X2']])
exog_infl = sm.add_constant(df[['X1', 'X2']])

# Fit Zero-Inflated Negative Binomial model
zinb_model = ZeroInflatedNegativeBinomialP(df['y'], exog, exog_infl=exog_infl)
zinb_results = zinb_model.fit()

# Print summary
print(zinb_results.summary())

# Access coefficients
print("\nCount model coefficients:")
print(zinb_results.params[:3])  # First 3 are for the count model
print("\nZero-inflation model coefficients:")
print(zinb_results.params[3:-1])  # Last 3 (excluding alpha) are for the zero-inflation model
print("\nOverdispersion parameter (alpha):")
print(zinb_results.params[-1])

# Predict
new_data = pd.DataFrame({'X1': [0.5, -0.5], 'X2': [-0.5, 0.5]})
new_exog = sm.add_constant(new_data)
predicted = zinb_results.predict(new_exog, exog_infl=new_exog)
print("\nPredicted counts for new data:")
print(predicted)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.316239
#          Iterations: 30
#          Function evaluations: 32
#          Gradient evaluations: 32
#                      ZeroInflatedNegativeBinomialP Regression Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                 1000
# Model:             ZeroInflatedNegativeBinomialP   Df Residuals:                      997
# Method:                                      MLE   Df Model:                            2
# Date:                           Sun, 29 Sep 2024   Pseudo R-squ.:                  0.1407
# Time:                                   21:14:52   Log-Likelihood:                -1316.2
# converged:                                  True   LL-Null:                       -1531.8
# Covariance Type:                       nonrobust   LLR p-value:                 2.386e-94
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# inflate_const     0.4585      0.086      5.309      0.000       0.289       0.628
# inflate_X1       -0.9208      0.095     -9.740      0.000      -1.106      -0.735
# inflate_X2        0.4278      0.090      4.758      0.000       0.252       0.604
# const             0.9803      0.051     19.107      0.000       0.880       1.081
# X1                0.4094      0.040     10.135      0.000       0.330       0.489
# X2               -0.5454      0.038    -14.387      0.000      -0.620      -0.471
# alpha             0.1644      0.035      4.651      0.000       0.095       0.234
# =================================================================================
#
# Count model coefficients:
# inflate_const    0.458504
# inflate_X1      -0.920778
# inflate_X2       0.427761
# dtype: float64
#
# Zero-inflation model coefficients:
# const    0.980286
# X1       0.409376
# X2      -0.545422
# dtype: float64
#
# Overdispersion parameter (alpha):
# 0.16436916460067033
#
# Predicted counts for new data:
# 0    2.378840
# 1    0.402872
# dtype: float64
# C:\Users\josep\AppData\Local\Temp\ipykernel_23564\2166287844.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(zinb_results.params[-1])

# %%
zinb_model.
# Out:
# <bound method DiscreteModel.cov_params_func_l1 of <statsmodels.discrete.count_model.ZeroInflatedNegativeBinomialP object at 0x000001AD90052390>>

# %%
# Function to calculate πi (zero-inflation probability)
def calc_pi(params_infl, exog_infl):
    linear_pred = np.dot(exog_infl, params_infl)
    return 1 / (1 + np.exp(-linear_pred))

# Function to calculate μi (mean of the count process)
def calc_mu(params_count, exog):
    return np.exp(np.dot(exog, params_count))

# Extract parameters
params_count = zinb_results.params[:3]  # First 3 are for the count model
params_infl = zinb_results.params[3:-1]  # Next 3 are for the zero-inflation model

# Calculate πi and μi for the original data
pi_i = calc_pi(params_infl, exog_infl)
mu_i = calc_mu(params_count, exog)

# Print some sample results
print("\nSample results for 5 observations:")
for i in range(100):
    print(f"Observation {i+1}:")
    print(f"  πi (zero-inflation probability): {pi_i[i]:.4f}")
    print(f"  μi (mean of count process): {mu_i[i]:.4f}")

# For new data
new_data = pd.DataFrame({'X1': [0.5, -0.5], 'X2': [-0.5, 0.5]})
new_exog = sm.add_constant(new_data)

pi_i_new = calc_pi(params_infl, new_exog)
mu_i_new = calc_mu(params_count, new_exog)

print("\nResults for new data:")
for i in range(len(new_data)):
    print(f"New observation {i+1}:")
    print(f"  πi (zero-inflation probability): {pi_i_new[i]:.4f}")
    print(f"  μi (mean of count process): {mu_i_new[i]:.4f}")
# Out:
# Sample results for 5 observations:
# Observation 1:
#   πi (zero-inflation probability): 0.8021
#   μi (mean of count process): 0.3954
# Observation 2:
#   πi (zero-inflation probability): 0.6587
#   μi (mean of count process): 1.6029
# Observation 3:
#   πi (zero-inflation probability): 0.8336
#   μi (mean of count process): 0.5361
# Observation 4:
#   πi (zero-inflation probability): 0.8630
#   μi (mean of count process): 0.2101
# Observation 5:
#   πi (zero-inflation probability): 0.8349
#   μi (mean of count process): 0.3124
# Observation 6:
#   πi (zero-inflation probability): 0.6155
#   μi (mean of count process): 4.2399
# Observation 7:
#   πi (zero-inflation probability): 0.7454
#   μi (mean of count process): 0.8311
# Observation 8:
#   πi (zero-inflation probability): 0.8710
#   μi (mean of count process): 0.8354
# Observation 9:
#   πi (zero-inflation probability): 0.7241
#   μi (mean of count process): 1.7031
# Observation 10:
#   πi (zero-inflation probability): 0.7346
#   μi (mean of count process): 1.2004
# Observation 11:
#   πi (zero-inflation probability): 0.8299
#   μi (mean of count process): 0.9030
# Observation 12:
#   πi (zero-inflation probability): 0.6598
#   μi (mean of count process): 0.8483
# Observation 13:
#   πi (zero-inflation probability): 0.7692
#   μi (mean of count process): 0.8410
# Observation 14:
#   πi (zero-inflation probability): 0.5442
#   μi (mean of count process): 2.7600
# Observation 15:
#   πi (zero-inflation probability): 0.8311
#   μi (mean of count process): 0.7495
# Observation 16:
#   πi (zero-inflation probability): 0.8337
#   μi (mean of count process): 0.7891
# Observation 17:
#   πi (zero-inflation probability): 0.8130
#   μi (mean of count process): 0.4399
# Observation 18:
#   πi (zero-inflation probability): 0.8596
#   μi (mean of count process): 0.9318
# Observation 19:
#   πi (zero-inflation probability): 0.7293
#   μi (mean of count process): 1.2998
# Observation 20:
#   πi (zero-inflation probability): 0.6405
#   μi (mean of count process): 3.6202
# Observation 21:
#   πi (zero-inflation probability): 0.3501
#   μi (mean of count process): 25.6284
# Observation 22:
#   πi (zero-inflation probability): 0.7038
#   μi (mean of count process): 1.1695
# Observation 23:
#   πi (zero-inflation probability): 0.8266
#   μi (mean of count process): 0.5969
# Observation 24:
#   πi (zero-inflation probability): 0.7816
#   μi (mean of count process): 1.9589
# Observation 25:
#   πi (zero-inflation probability): 0.7262
#   μi (mean of count process): 0.4070
# Observation 26:
#   πi (zero-inflation probability): 0.6936
#   μi (mean of count process): 4.3009
# Observation 27:
#   πi (zero-inflation probability): 0.8277
#   μi (mean of count process): 0.9696
# Observation 28:
#   πi (zero-inflation probability): 0.8169
#   μi (mean of count process): 1.1815
# Observation 29:
#   πi (zero-inflation probability): 0.7307
#   μi (mean of count process): 0.6219
# Observation 30:
#   πi (zero-inflation probability): 0.8659
#   μi (mean of count process): 0.3275
# Observation 31:
#   πi (zero-inflation probability): 0.8107
#   μi (mean of count process): 0.9934
# Observation 32:
#   πi (zero-inflation probability): 0.7427
#   μi (mean of count process): 1.1844
# Observation 33:
#   πi (zero-inflation probability): 0.6747
#   μi (mean of count process): 3.2787
# Observation 34:
#   πi (zero-inflation probability): 0.6316
#   μi (mean of count process): 7.3325
# Observation 35:
#   πi (zero-inflation probability): 0.6051
#   μi (mean of count process): 3.0083
# Observation 36:
#   πi (zero-inflation probability): 0.6138
#   μi (mean of count process): 2.1603
# Observation 37:
#   πi (zero-inflation probability): 0.7204
#   μi (mean of count process): 0.7766
# Observation 38:
#   πi (zero-inflation probability): 0.7416
#   μi (mean of count process): 0.7257
# Observation 39:
#   πi (zero-inflation probability): 0.6461
#   μi (mean of count process): 2.6842
# Observation 40:
#   πi (zero-inflation probability): 0.8612
#   μi (mean of count process): 0.9775
# Observation 41:
#   πi (zero-inflation probability): 0.4111
#   μi (mean of count process): 8.4827
# Observation 42:
#   πi (zero-inflation probability): 0.5583
#   μi (mean of count process): 6.6539
# Observation 43:
#   πi (zero-inflation probability): 0.4875
#   μi (mean of count process): 9.8724
# Observation 44:
#   πi (zero-inflation probability): 0.7633
#   μi (mean of count process): 0.4228
# Observation 45:
#   πi (zero-inflation probability): 0.4975
#   μi (mean of count process): 4.6688
# Observation 46:
#   πi (zero-inflation probability): 0.6394
#   μi (mean of count process): 2.8316
# Observation 47:
#   πi (zero-inflation probability): 0.5572
#   μi (mean of count process): 6.0397
# Observation 48:
#   πi (zero-inflation probability): 0.8355
#   μi (mean of count process): 0.5983
# Observation 49:
#   πi (zero-inflation probability): 0.5748
#   μi (mean of count process): 7.0901
# Observation 50:
#   πi (zero-inflation probability): 0.7956
#   μi (mean of count process): 1.3351
# Observation 51:
#   πi (zero-inflation probability): 0.7323
#   μi (mean of count process): 2.6513
# Observation 52:
#   πi (zero-inflation probability): 0.8356
#   μi (mean of count process): 0.7558
# Observation 53:
#   πi (zero-inflation probability): 0.7019
#   μi (mean of count process): 2.3681
# Observation 54:
#   πi (zero-inflation probability): 0.4812
#   μi (mean of count process): 7.3475
# Observation 55:
#   πi (zero-inflation probability): 0.3185
#   μi (mean of count process): 6.3020
# Observation 56:
#   πi (zero-inflation probability): 0.7412
#   μi (mean of count process): 1.1562
# Observation 57:
#   πi (zero-inflation probability): 0.8511
#   μi (mean of count process): 0.8357
# Observation 58:
#   πi (zero-inflation probability): 0.6021
#   μi (mean of count process): 2.0567
# Observation 59:
#   πi (zero-inflation probability): 0.7078
#   μi (mean of count process): 2.4941
# Observation 60:
#   πi (zero-inflation probability): 0.7671
#   μi (mean of count process): 1.6652
# Observation 61:
#   πi (zero-inflation probability): 0.6435
#   μi (mean of count process): 3.2138
# Observation 62:
#   πi (zero-inflation probability): 0.8190
#   μi (mean of count process): 1.2955
# Observation 63:
#   πi (zero-inflation probability): 0.6286
#   μi (mean of count process): 3.6781
# Observation 64:
#   πi (zero-inflation probability): 0.5798
#   μi (mean of count process): 7.4650
# Observation 65:
#   πi (zero-inflation probability): 0.7309
#   μi (mean of count process): 1.4010
# Observation 66:
#   πi (zero-inflation probability): 0.6474
#   μi (mean of count process): 2.6956
# Observation 67:
#   πi (zero-inflation probability): 0.5686
#   μi (mean of count process): 7.3040
# Observation 68:
#   πi (zero-inflation probability): 0.7615
#   μi (mean of count process): 1.0402
# Observation 69:
#   πi (zero-inflation probability): 0.6115
#   μi (mean of count process): 4.1187
# Observation 70:
#   πi (zero-inflation probability): 0.6846
#   μi (mean of count process): 1.8010
# Observation 71:
#   πi (zero-inflation probability): 0.8631
#   μi (mean of count process): 0.5199
# Observation 72:
#   πi (zero-inflation probability): 0.8597
#   μi (mean of count process): 0.7619
# Observation 73:
#   πi (zero-inflation probability): 0.8146
#   μi (mean of count process): 0.5396
# Observation 74:
#   πi (zero-inflation probability): 0.7784
#   μi (mean of count process): 2.6715
# Observation 75:
#   πi (zero-inflation probability): 0.7497
#   μi (mean of count process): 1.1337
# Observation 76:
#   πi (zero-inflation probability): 0.5468
#   μi (mean of count process): 4.4399
# Observation 77:
#   πi (zero-inflation probability): 0.5726
#   μi (mean of count process): 4.5723
# Observation 78:
#   πi (zero-inflation probability): 0.7884
#   μi (mean of count process): 1.7214
# Observation 79:
#   πi (zero-inflation probability): 0.7895
#   μi (mean of count process): 1.4585
# Observation 80:
#   πi (zero-inflation probability): 0.6951
#   μi (mean of count process): 1.7284
# Observation 81:
#   πi (zero-inflation probability): 0.6731
#   μi (mean of count process): 3.8950
# Observation 82:
#   πi (zero-inflation probability): 0.8208
#   μi (mean of count process): 0.6027
# Observation 83:
#   πi (zero-inflation probability): 0.6996
#   μi (mean of count process): 1.3298
# Observation 84:
#   πi (zero-inflation probability): 0.7089
#   μi (mean of count process): 4.2662
# Observation 85:
#   πi (zero-inflation probability): 0.8592
#   μi (mean of count process): 0.3384
# Observation 86:
#   πi (zero-inflation probability): 0.8996
#   μi (mean of count process): 0.1960
# Observation 87:
#   πi (zero-inflation probability): 0.8841
#   μi (mean of count process): 0.3419
# Observation 88:
#   πi (zero-inflation probability): 0.7980
#   μi (mean of count process): 1.2938
# Observation 89:
#   πi (zero-inflation probability): 0.5430
#   μi (mean of count process): 5.6645
# Observation 90:
#   πi (zero-inflation probability): 0.7996
#   μi (mean of count process): 0.6125
# Observation 91:
#   πi (zero-inflation probability): 0.7850
#   μi (mean of count process): 1.5741
# Observation 92:
#   πi (zero-inflation probability): 0.8330
#   μi (mean of count process): 0.4649
# Observation 93:
#   πi (zero-inflation probability): 0.8765
#   μi (mean of count process): 0.6477
# Observation 94:
#   πi (zero-inflation probability): 0.8557
#   μi (mean of count process): 0.4703
# Observation 95:
#   πi (zero-inflation probability): 0.4884
#   μi (mean of count process): 2.8573
# Observation 96:
#   πi (zero-inflation probability): 0.7890
#   μi (mean of count process): 0.7940
# Observation 97:
#   πi (zero-inflation probability): 0.6423
#   μi (mean of count process): 2.1422
# Observation 98:
#   πi (zero-inflation probability): 0.8516
#   μi (mean of count process): 0.2970
# Observation 99:
#   πi (zero-inflation probability): 0.6990
#   μi (mean of count process): 1.6333
# Observation 100:
#   πi (zero-inflation probability): 0.6863
#   μi (mean of count process): 1.4507
#
# Results for new data:
# New observation 1:
#   πi (zero-inflation probability): 0.8112
#   μi (mean of count process): 0.8059
# New observation 2:
#   πi (zero-inflation probability): 0.6231
#   μi (mean of count process): 3.1043
